# %% [markdown]
# <a href="https://colab.research.google.com/github/Edersao/Curso_Data_Scientist/blob/main/Prueba_modulo_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Crear un **dataframe** que contenga 5 registros de deportistas famosos y que tenga de columnas el nombre y el deporte que practican:

# %%
import pandas as pd
deportistas = pd.DataFrame(
    {
       'Nombre':['Michel Jordan','Lionel Messi', 'Tom Brady', 'Serena Williams'],
       'Deporte':['Baloncesto','Fútbol','Fútbol Americano','Tenis']
    })
deportistas
# Out:
#             Nombre           Deporte
# 0    Michel Jordan        Baloncesto
# 1     Lionel Messi            Fútbol
# 2        Tom Brady  Fútbol Americano
# 3  Serena Williams             Tenis

# %% [markdown]
# 2. Crea una serie con la edad de los deportistas y agrégala al **dataframe**.

# %%
edad= [58,33,43,39]
deportistas['Edad']=edad
deportistas
# Out:
#             Nombre           Deporte  Edad
# 0    Michel Jordan        Baloncesto    58
# 1     Lionel Messi            Fútbol    33
# 2        Tom Brady  Fútbol Americano    43
# 3  Serena Williams             Tenis    39

# %% [markdown]
# 3. Lee el archivo que se encuentra en la siguiente liga: [vaccionation_tweets.csv](https://drive.google.com/file/d/15dBDgLXME9iLu_9tV8AMXtOI_DHZwAeJ/view?usp=drive_link),
# el cual cuenta con información relacionada con los Tweets de la vacuna contra la COVID-19, recuperado de la plataforma Kaggle.
# 4. Mostar los 7 primeros.
# 5. Mostrar los últimos 4 registros
# 6. Mostar la estructura del **dataframe**.

# %%
#Para acceder a los archivos de mi drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
vacunas_COVID19= pd.read_csv('/content/drive/MyDrive/Colab Notebooks/vaccination_tweets.csv')
vacunas_COVID19.head(7)
# Out:
#              id             user_name                user_location  \
# 0  1.340000e+18            Rachel Roh    La Crescenta-Montrose, CA
# 1  1.340000e+18           Albert Fong            San Francisco, CA
# 2  1.340000e+18              eli🇱🇹🇪🇺👌                     Your Bed
# 3  1.340000e+18         Charles Adler       Vancouver, BC - Canada
# 4  1.340000e+18  Citizen News Channel                          NaN
# 5  1.340000e+18                   Dee          Birmingham, England
# 6  1.340000e+18     Gunther Fehlinger  Austria, Ukraine and Kosovo
#
#                                     user_description      user_created  \
# 0  Aggregator of Asian American news; scanning di...  08/04/2009 17:52
# 1  Marketing dude, tech geek, heavy metal & '80s ...  21/09/2009 15:27
# 2                                     heil, hydra 🖐☺  25/06/2020 23:30
# 3  Hosting "CharlesAdlerTonight" Global News Radi...  10/09/2008 11:28
# 4  Citizen News Channel bringing you an alternati...  23/04/2020 17:58
# ...

# %%
print('últmos 4 regsitros')
vacunas_COVID19.tail(4)
# Out:
# últmos 4 regsitros
#                 id        user_name                   user_location  \
# 4276  1.350000e+18   SUR in English                   Malaga, Spain
# 4277  1.350000e+18  Melissa coleman                     Borehamwood
# 4278  1.350000e+18     The Insider🦉  J.Laurel St, Sn Miguel, Manila
# 4279  1.350000e+18    Dr Ai Lyn Tan                       Leeds, UK
#
#                                        user_description      user_created  \
# 4276  SUR in English, the English-language newspaper...  09/10/2012 12:42
# 4277  I am a administrator with the vaccination team...  02/12/2012 13:21
# 4278  #LoresAndApothegms𓅓 \nfrom the former summer h...  11/11/2020 16:11
# 4279  Associate Professor. Rheumatologist. Research:...  13/12/2012 15:38
#
#       user_followers  user_friends  user_favourites  user_verified  \
# 4276            5438           629              217          False
# 4277             788          1858             6698          False
# ...

# %%
print('8. estructura el dataframe')
vacunas_COVID19.info()
# Out:
# 8. estructura el dataframe
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4277 entries, 3 to 4279
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                4277 non-null   float64
#  1   user_name         4277 non-null   object
#  2   user_location     3395 non-null   object
#  3   user_description  4006 non-null   object
#  4   user_created      4277 non-null   object
#  5   user_followers    4277 non-null   int64
#  6   user_friends      4277 non-null   int64
#  7   user_favourites   4277 non-null   int64
#  8   user_verified     4277 non-null   bool
#  9   date              4277 non-null   object
#  10  text              4277 non-null   object
#  11  hashtags          3186 non-null   object
#  12  source            4276 non-null   object
#  13  retweets          4277 non-null   int64
#  14  favorites         4277 non-null   int64
#  15  is_retweet        4277 non-null   bool
# ...

# %% [markdown]
# 7. Eliminar del **dataframe** los tres primeros registros y vuelve a usar la función **head** para mostra rlos primeros 5 registros.

# %%
vacunas_COVID19=vacunas_COVID19.drop(index=[0,1,2])
vacunas_COVID19.head()
# Out:
#              id             user_name                user_location  \
# 3  1.340000e+18         Charles Adler       Vancouver, BC - Canada
# 4  1.340000e+18  Citizen News Channel                          NaN
# 5  1.340000e+18                   Dee          Birmingham, England
# 6  1.340000e+18     Gunther Fehlinger  Austria, Ukraine and Kosovo
# 7  1.340000e+18   Dr.Krutika Kuppalli                          NaN
#
#                                     user_description      user_created  \
# 3  Hosting "CharlesAdlerTonight" Global News Radi...  10/09/2008 11:28
# 4  Citizen News Channel bringing you an alternati...  23/04/2020 17:58
# 5  Gastroenterology trainee, Clinical Research Fe...  26/01/2020 21:43
# 6  End North Stream 2 now - the pipeline of corru...  10/06/2013 17:49
# 7  ID, Global Health, VHF, Pandemic Prep, Emergin...  25/03/2019 04:14
#
#    user_followers  user_friends  user_favourites  user_verified  \
# 3           49165          3933            21853           True
# ...

# %% [markdown]
# 8. Elimina del **dataframe** las columnas **user_created** y **user_description** y vuelve a utilizar la función **tail** para mostrar los ultimos 3 registros.

# %%
vacunas_COVID19=vacunas_COVID19.drop(columns=['user_created','user_description'])
vacunas_COVID19.tail(3)
# Out:
#                 id        user_name                   user_location  \
# 4277  1.350000e+18  Melissa coleman                     Borehamwood
# 4278  1.350000e+18     The Insider🦉  J.Laurel St, Sn Miguel, Manila
# 4279  1.350000e+18    Dr Ai Lyn Tan                       Leeds, UK
#
#       user_followers  user_friends  user_favourites  user_verified  \
# 4277             788          1858             6698          False
# 4278              35           627               17          False
# 4279            5144           184            10062          False
#
#                   date                                               text  \
# 4277  14/01/2021 10:37  First Pfizer covid 19 vaccine dose done ✅ very...
# 4278  14/01/2021 09:36  A ‘healthy’ doctor died two weeks after gettin...
# 4279  14/01/2021 08:43  Day 21 post #covid19 #vaccination\n\nMy 2nd ja...
#
#                                 hashtags               source  retweets  \
# ...

# %% [markdown]
# 9. Agrega columna llamada **revisado** con el valor **True** para todos los registros y muestra los primeros $2$ registros.

# %%
vacunas_COVID19['revisado']= True
vacunas_COVID19.tail(2)
# Out:
#                 id      user_name                   user_location  \
# 4278  1.350000e+18   The Insider🦉  J.Laurel St, Sn Miguel, Manila
# 4279  1.350000e+18  Dr Ai Lyn Tan                       Leeds, UK
#
#       user_followers  user_friends  user_favourites  user_verified  \
# 4278              35           627               17          False
# 4279            5144           184            10062          False
#
#                   date                                               text  \
# 4278  14/01/2021 09:36  A ‘healthy’ doctor died two weeks after gettin...
# 4279  14/01/2021 08:43  Day 21 post #covid19 #vaccination\n\nMy 2nd ja...
#
#                         hashtags               source  retweets  favorites  \
# 4278                 ['Vaccine']  Twitter for Android         0          0
# 4279  ['covid19', 'vaccination']  Twitter for Android         3          5
#
#       is_retweet  revisado
# 4278       False      True
# 4279       False      True

# %% [markdown]
# 10. Almacena el nuevo **dataframe** en:
#   - Un archivo separado por comas llamado **tweets_revisados.csv**
#   - Un archivo de **Excel** llamado **tweets_procesados.xlsx.

# %%
vacunas_COVID19.to_csv('/content/drive/MyDrive/Colab Notebooks/datos/tweets_revisados.csv')
vacunas_COVID19.to_excel('/content/drive/MyDrive/Colab Notebooks/datos/tweets_procesados.xlsx')
