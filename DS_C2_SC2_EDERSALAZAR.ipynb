# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# a. Extraer la información del archivo.

# %%
import pandas as pd
vacunas=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/datos/1695860027103-country_vaccinations.csv', parse_dates=['date'])
vacunas.head()
# Out:
#        country iso_code       date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG 2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG 2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG 2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG 2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG 2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN              1367.0
# 2                      NaN                     NaN              1367.0
# 3                      NaN                     NaN              1367.0
# 4                      NaN                     NaN              1367.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# ...

# %% [markdown]
# b. Mostrar la estructura y tipos de datos de cada columna para identificar qué operaciones puedes realizar con cada una de ellas, asegurándote que las columnas con fechas sean del tipo **datetime64**.

# %%
vacunas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86512 entries, 0 to 86511
# Data columns (total 15 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   country                              86512 non-null  object
#  1   iso_code                             86512 non-null  object
#  2   date                                 86512 non-null  datetime64[ns]
#  3   total_vaccinations                   43607 non-null  float64
#  4   people_vaccinated                    41294 non-null  float64
#  5   people_fully_vaccinated              38802 non-null  float64
#  6   daily_vaccinations_raw               35362 non-null  float64
#  7   daily_vaccinations                   86213 non-null  float64
#  8   total_vaccinations_per_hundred       43607 non-null  float64
#  9   people_vaccinated_per_hundred        41294 non-null  float64
#  10  people_fully_vaccinated_per_hundred  38802 non-null  float64
# ...

# %% [markdown]
# c. Determinar la cantidad de vacunas aplicadas de cada compañía (con base en cómo lo reporta cada país en la columna **vaccines**, en otras palabras, agrupe por vaccines y realice la sumatoria).

# %%
v=vacunas[['country','vaccines','daily_vaccinations','date']]
vp=v.groupby('vaccines').sum()
vp.head()
# Out:
# <ipython-input-72-6169950e52b4>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   vp=v.groupby('vaccines').sum()
#                                                     daily_vaccinations
# vaccines
# Abdala, Johnson&Johnson, Oxford/AstraZeneca, Pf...           9616160.0
# Abdala, Moderna, Oxford/AstraZeneca, Pfizer/Bio...         201816053.0
# Abdala, Sinopharm/Beijing, Sinovac, Soberana02,...          37861146.0
# Abdala, Soberana Plus, Soberana02                           33802957.0
# COVIran Barekat, Covaxin, FAKHRAVAC, Oxford/Ast...         146357015.0

# %% [markdown]
# d. Obtener la cantidad de vacunas aplicadas en todo el mundo

# %%
print('En todo se aplicarón un total de ',vp['daily_vaccinations'].sum(),' vacunas desde ',min(v['date']),' hasta ',max(v['date']))
# Out:
# En todo se aplicarón un total de  11320239871.0  vacunas desde  2020-12-02 00:00:00  hasta  2022-03-29 00:00:00

# %% [markdown]
# e. Calcular el promedio de vacunas aplicadas por país.

# %%
vp_m=v.groupby('country').mean().round(2)
print('El promedio de vacunas aplicadas por pais:',vp_m,sep=',')
# Out:
# El promedio de vacunas aplicadas por pais:,                   daily_vaccinations
# country
# Afghanistan                  14610.68
# Albania                       6276.21
# Algeria                      33904.36
# Andorra                        367.72
# Angola                       44821.46
# ...                               ...
# Wales                        15518.41
# Wallis and Futuna               33.89
# Yemen                         2556.12
# Zambia                        9649.81
# Zimbabwe                     21669.07
#
# [223 rows x 1 columns]
# <ipython-input-70-8c9c9c13d531>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   vp_m=v.groupby('country').mean().round(2)

# %% [markdown]
# f. Determina la cantidad de vacunas aplicadas el día 29/01/21 en todo el mundo

# %%
vd = vacunas[['date','daily_vaccinations']].groupby([vacunas['date'].dt.year,vacunas['date'].dt.month, vacunas['date'].dt.day]).sum()
print('La cantidad de vacunas aplicadas  el día 29/01/21 en todo el mundo fue de: ',vd.loc[2021, 1,29][0])
# Out:
# La cantidad de vacunas aplicadas  el día 29/01/21 en todo el mundo fue de:  4884052.0
# <ipython-input-147-d20e4d9b9142>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   vd = vacunas[['date','daily_vaccinations']].groupby([vacunas['date'].dt.year,vacunas['date'].dt.month, vacunas['date'].dt.day]).sum()

# %% [markdown]
# g, Crea un dataframe nuevo denominado **conDiferencias** que contenga los datos originales y una columna derivada (_diferencias_) con las diferencias de aplicación entre las columnas **daily_vaccinations** y **daiy_vaccinations_raws**.

# %%
conDiferencias= vacunas
conDiferencias['diferencias']= conDiferencias['daily_vaccinations'] - conDiferencias['daily_vaccinations_raw']
conDiferencias.head()
# Out:
#        country iso_code       date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG 2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG 2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG 2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG 2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG 2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN              1367.0
# 2                      NaN                     NaN              1367.0
# 3                      NaN                     NaN              1367.0
# 4                      NaN                     NaN              1367.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# ...

# %% [markdown]
# h. Obtener el periodo de tiempo entre el registro con fecha más reciente y el registro con fecha más antigua.

# %%
print('El periodo de tiempo entre los registros son de ',min(conDiferencias['date']),' hasta ',max(conDiferencias['date']))
print('donde la fecha más reciente es', str(max(conDiferencias['date']))[0:-9],'y la más antigua ',str(min(conDiferencias['date']))[0:-9])
# Out:
# El periodo de tiempo entre los registros son de  2020-12-02 00:00:00  hasta  2022-03-29 00:00:00
# donde la fecha más reciente es 2022-03-29 y la más antigua  2020-12-02

# %% [markdown]
# i. Crear un dataframe nuevo denominado **conCantidad** que contenga los datos originales y una columna derivada (_canVac_) con la cantidad de vacunas utilizadas cada día (usar columna vaccines y separar por el carácter **,**).

# %%
conCantidad=vacunas
conCantidad['canVac']=conCantidad['vaccines'].str.split(', ')
conCantidad.head()
# Out:
#        country iso_code       date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG 2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG 2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG 2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG 2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG 2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN              1367.0
# 2                      NaN                     NaN              1367.0
# 3                      NaN                     NaN              1367.0
# 4                      NaN                     NaN              1367.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# ...

# %% [markdown]
# j. Generar un dataframe deniminado **antes20**  con todos los registros qe se hayan realizado antes del 20 de diciembre de 2020

# %%
antes20=vacunas[vacunas['date']< '2020-12-20']
antes20.head()
# Out:
#       country iso_code       date  total_vaccinations  people_vaccinated  \
# 13403  Canada      CAN 2020-12-14                 5.0                5.0
# 13404  Canada      CAN 2020-12-15               727.0              727.0
# 13405  Canada      CAN 2020-12-16              3025.0             3025.0
# 13406  Canada      CAN 2020-12-17              7279.0             7279.0
# 13407  Canada      CAN 2020-12-18             11296.0            11296.0
#
#        people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 13403                      NaN                     NaN                 NaN
# 13404                      NaN                   722.0               722.0
# 13405                      NaN                  2298.0              1510.0
# 13406                      NaN                  4254.0              2425.0
# 13407                      NaN                  4017.0              2823.0
#
#        total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# ...

# %% [markdown]
# k. Obtener un dataframe denominado **pfizer** con todos los registros donde se haya utilizado la vacuna _Pfizer_.

# %%
pfizer = vacunas[vacunas['vaccines'].str.contains('Pfizer',case=False) == True]

# %% [markdown]
# l. Almacenar los dataframes generados (conDiferencias, conCantidad, antes20 y pfizer) en un archivo de Excel denominado **resultadosRetos.xlsx,**, donde cada dataframe ocupe una hoja diferente.

# %%
with pd.ExcelWriter("/content/drive/MyDrive/Colab Notebooks/datos/resultadosReto.xlsx") as writer:
    conDiferencias.to_excel(writer, sheet_name="conDiferencias")
    conCantidad.to_excel(writer, sheet_name="conCantidad")
    antes20.to_excel(writer,sheet_name="antes20")
    pfizer.to_excel(writer, sheet_name="Pfizer")
